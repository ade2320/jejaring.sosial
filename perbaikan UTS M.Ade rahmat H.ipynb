# %%
import networkx as nx 
import matplotlib.pyplot as plt
G=nx.DiGraph() 

G.add_edge('UU Nomor 7 Tahun 2011','UUD 1945') 
G.add_edge('UU Nomor 7 Tahun 2011','UU Nomor 23 Tahun 1999') 

G.add_edge('UU Nomor 42 Tahun 2008','UUD 1945')
G.add_edge('UU Nomor 42 Tahun 2008','UU Nomor 22 Tahun 2007')


G.add_edge('UU Nomor 46 Tahun 2009','UUD 1945')
G.add_edge('UU Nomor 46 Tahun 2009','UU Nomor 8 Tahun 1981')


G.add_edge('UU Nomor 11 Tahun 2012','UUD 1945')
G.add_edge('UU Nomor 11 Tahun 2012','UU Nomor 39 Tahun 1999')


G.add_edge('UU Nomor 5 Tahun 2018','UUD 1945')
G.add_edge('UU Nomor 5 Tahun 2018','UU Nomor 15 Tahun 2003')

G.add_edge('UU Nomor 13 Tahun 2011','UUD 1945')
G.add_edge('UU Nomor 13 Tahun 2011','UU Nomor 11 Tahun 2009')

nx.draw_networkx(G)
plt.axis('off')
plt.show() # display
